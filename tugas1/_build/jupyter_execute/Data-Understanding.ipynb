# %% [markdown]
# # Data Understanding
#
# Proses *Data Understanding* merupakan tahap awal dalam siklus analisis data yang berfokus pada pengumpulan, penelaahan, dan evaluasi dataset. Tujuan utamanya adalah memastikan bahwa data yang digunakan benar-benar relevan dengan permasalahan bisnis serta layak diproses lebih lanjut dalam tahap analisis.
#
# Tahapan utama dalam memahami data meliputi:
#
# ### 1. Pengumpulan Data
# Mengidentifikasi serta memperoleh data dari berbagai sumber yang berhubungan dengan permasalahan yang sedang dikaji.
#
# ### 2. Deskripsi Data
# Menganalisis struktur data, seperti jumlah baris dan kolom, serta memahami tipe variabel atau atribut yang tersedia.
#
# ### 3. Eksplorasi Data
# Melakukan penelusuran awal untuk menemukan pola, hubungan, maupun penyimpangan dalam data. Tahapan ini biasanya menggunakan metode statistik deskriptif dan visualisasi data.
#
# ### 4. Kualitas Data
# Menilai kelengkapan, akurasi, dan konsistensi data untuk memastikan dataset memiliki mutu yang memadai sebelum dianalisis lebih jauh.

# %%
# %pip install seaborn
# %pip install pycaret
# Import library yang diperlukan
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Import PyCaret untuk EDA dan classification
try:
    from pycaret.datasets import get_data
    from pycaret.classification import *
    from pycaret.anomaly import *
    print("PyCaret berhasil diimport")
except ImportError:
    print("PyCaret tidak tersedia. Install dengan: pip install pycaret")

# visualisasi
plt.style.use('default')
sns.set_palette("husl")

print("Library berhasil diimport")
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from seaborn) (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pycaret in c:\xampp\htdocs\psds\.venv\lib\site-packages (3.3.2)
# Requirement already satisfied: ipython>=5.5.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (9.5.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (8.1.7)
# Requirement already satisfied: tqdm>=4.62.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (4.67.1)
# Requirement already satisfied: numpy<1.27,>=1.21 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (1.26.4)
# Requirement already satisfied: pandas<2.2.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (2.1.4)
# Requirement already satisfied: jinja2>=3 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (3.1.6)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (1.11.4)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (1.3.2)
# Requirement already satisfied: scikit-learn>1.4.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (1.4.2)
# Requirement already satisfied: pyod>=1.1.3 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (2.0.5)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (0.14.0)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (2.7.0)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (4.6.0)
# Requirement already satisfied: numba>=0.55.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (0.61.2)
# Requirement already satisfied: requests>=2.27.1 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (2.32.5)
# Requirement already satisfied: psutil>=5.9.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (7.0.0)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (3.0.2)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (8.7.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (5.10.4)
# Requirement already satisfied: cloudpickle in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (3.1.1)
# Requirement already satisfied: deprecation>=2.1.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: xxhash in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (3.5.0)
# Requirement already satisfied: matplotlib<3.8.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (3.7.5)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (6.3.0)
# Requirement already satisfied: kaleido>=0.2.1 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (1.1.0)
# Requirement already satisfied: schemdraw==0.15 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (0.11.0)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (0.14.5)
# Requirement already satisfied: sktime==0.26.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (0.26.0)
# Requirement already satisfied: tbats>=1.1.3 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: packaging in c:\xampp\htdocs\psds\.venv\lib\site-packages (from sktime==0.26.0->pycaret) (25.0)
# Requirement already satisfied: scikit-base<0.8.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from sktime==0.26.0->pycaret) (0.7.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from matplotlib<3.8.0->pycaret) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from matplotlib<3.8.0->pycaret) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.4.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from matplotlib<3.8.0->pycaret) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from matplotlib<3.8.0->pycaret) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from matplotlib<3.8.0->pycaret) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pandas<2.2.0->pycaret) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pandas<2.2.0->pycaret) (2025.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from scikit-learn>1.4.0->pycaret) (3.6.0)
# Requirement already satisfied: patsy>=0.5.1 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from category-encoders>=2.4.0->pycaret) (1.0.1)
# Requirement already satisfied: zipp>=3.20 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.23.0)
# Requirement already satisfied: colorama in c:\xampp\htdocs\psds\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.6)
# Requirement already satisfied: decorator in c:\xampp\htdocs\psds\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\xampp\htdocs\psds\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\xampp\htdocs\psds\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (2.19.2)
# Requirement already satisfied: stack_data in c:\xampp\htdocs\psds\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (4.15.0)
# Requirement already satisfied: wcwidth in c:\xampp\htdocs\psds\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.5.0->pycaret) (0.2.13)
# Requirement already satisfied: comm>=0.1.3 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.15)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.5)
# Requirement already satisfied: choreographer>=1.0.10 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from kaleido>=0.2.1->pycaret) (1.0.10)
# Requirement already satisfied: logistro>=1.0.8 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from kaleido>=0.2.1->pycaret) (1.1.0)
# Requirement already satisfied: orjson>=3.10.15 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from kaleido>=0.2.1->pycaret) (3.11.3)
# Requirement already satisfied: pytest-timeout>=2.4.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from kaleido>=0.2.1->pycaret) (2.4.0)
# Requirement already satisfied: simplejson>=3.19.3 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from choreographer>=1.0.10->kaleido>=0.2.1->pycaret) (3.20.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from nbformat>=4.2.0->pycaret) (5.8.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.27.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (4.4.0)
# Requirement already satisfied: pywin32>=300 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (311)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from numba>=0.55.0->pycaret) (0.44.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from plotly>=5.14.0->pycaret) (2.5.0)
# Requirement already satisfied: dash>=2.11.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.2.0)
# Requirement already satisfied: tsdownsample>=0.1.3 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.4.1)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (3.1.2)
# Requirement already satisfied: Werkzeug<3.2 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (3.1.3)
# Requirement already satisfied: retrying in c:\xampp\htdocs\psds\.venv\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.4.2)
# Requirement already satisfied: nest-asyncio in c:\xampp\htdocs\psds\.venv\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.6.0)
# Requirement already satisfied: setuptools in c:\xampp\htdocs\psds\.venv\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (80.9.0)
# Requirement already satisfied: blinker>=1.9.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (8.2.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pmdarima>=2.0.4->pycaret) (3.1.4)
# Requirement already satisfied: urllib3 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pmdarima>=2.0.4->pycaret) (2.5.0)
# Requirement already satisfied: pytest>=7.0.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (8.4.2)
# Requirement already satisfied: iniconfig>=1 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (1.6.0)
# Requirement already satisfied: six>=1.5 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib<3.8.0->pycaret) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from requests>=2.27.1->pycaret) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from requests>=2.27.1->pycaret) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from requests>=2.27.1->pycaret) (2025.8.3)
# Requirement already satisfied: executing>=1.2.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from stack_data->ipython>=5.5.0->pycaret) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\xampp\htdocs\psds\.venv\lib\site-packages (from stack_data->ipython>=5.5.0->pycaret) (3.0.0)
# Requirement already satisfied: pure-eval in c:\xampp\htdocs\psds\.venv\lib\site-packages (from stack_data->ipython>=5.5.0->pycaret) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 6
#       4 import pandas as pd
#       5 import numpy as np
# ----> 6 import matplotlib.pyplot as plt
#       7 import seaborn as sns
#       8 import warnings
#
# File C:\xampp\htdocs\PSDs\.venv\Lib\site-packages\matplotlib\__init__.py:142
#     138 from packaging.version import parse as parse_version
#     140 # cbook must import matplotlib only within function
#     141 # definitions, so it is safe to import from it here.
# --> 142 from . import _api, _version, cbook, _docstring, rcsetup
#     143 from matplotlib.cbook import sanitize_sequence
#     144 from matplotlib._api import MatplotlibDeprecationWarning
#
# File C:\xampp\htdocs\PSDs\.venv\Lib\site-packages\matplotlib\rcsetup.py:28
#      26 from matplotlib.cbook import ls_mapper
#      27 from matplotlib.colors import Colormap, is_color_like
# ---> 28 from matplotlib._fontconfig_pattern import parse_fontconfig_pattern
#      29 from matplotlib._enums import JoinStyle, CapStyle
#      31 # Don't let the original cycler collide with our validating cycler
#
# File C:\xampp\htdocs\PSDs\.venv\Lib\site-packages\matplotlib\_fontconfig_pattern.py:15
#      12 from functools import lru_cache, partial
#      13 import re
# ---> 15 from pyparsing import (
#      16     Group, Optional, ParseException, Regex, StringEnd, Suppress, ZeroOrMore)
#      18 from matplotlib import _api
#      21 _family_punc = r'\\\-:,'
#
# File C:\xampp\htdocs\PSDs\.venv\Lib\site-packages\pyparsing\__init__.py:134
#     131 __author__ = "Paul McGuire <ptmcg.gm+pyparsing@gmail.com>"
#     133 from .util import *
# --> 134 from .exceptions import *
#     135 from .actions import *
#     136 from .core import __diag__, __compat__
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:936, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:1032, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1131, in get_data(self, path)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Load Dataset
#
# Dataset Iris akan dimuat dari file CSV. Pastikan file CSV berada di folder yang sama atau sesuaikan path-nya.

# %%
# Load dataset Iris dari file CSV atau PyCaret
try:
    df = pd.read_csv('data_iris.csv', delimiter=';')

    numeric_columns = ['sepal length', 'sepal width', 'petal length', 'petal width']
    for col in numeric_columns:
        if col in df.columns:
            df[col] = df[col].astype(str).str.replace(',', '.').astype(float)

    if 'Class' in df.columns:
        df['species_name'] = df['Class'].map({
            'Iris-setosa': 'setosa',
            'Iris-versicolor': 'versicolor',
            'Iris-virginica': 'virginica'
        })
        df['species'] = df['species_name'].map({
            'setosa': 0, 'versicolor': 1, 'virginica': 2
        })

    df = df.rename(columns={
        'sepal length': 'sepal length (cm)',
        'sepal width': 'sepal width (cm)',
        'petal length': 'petal length (cm)',
        'petal width': 'petal width (cm)'
    })

    if 'id' in df.columns:
        df = df.drop('id', axis=1)

    print("✅ Dataset Iris berhasil dimuat dari data_iris.csv")

except FileNotFoundError:
    print("⚠️ File lokal tidak ditemukan. Menggunakan dataset Iris dari PyCaret...")
    from pycaret.datasets import get_data
    try:
        df = get_data('iris')

        df['species_num'] = df['species'].map({
            'setosa': 0, 'versicolor': 1, 'virginica': 2
        })
        df['species_name'] = df['species']

        print("✅ Dataset Iris berhasil dimuat dari PyCaret")
    except Exception as e:
        print("❌ Error: Tidak dapat memuat dataset dari PyCaret")
        print(e)

print(f"\nUkuran dataset: {df.shape[0]} baris, {df.shape[1]} kolom")
print(f"Kolom dataset: {list(df.columns)}")

df.head()
# Out:
# ✅ Dataset Iris berhasil dimuat dari data_iris.csv
#
# Ukuran dataset: 150 baris, 1 kolom
# Kolom dataset: ['id,Class,sepal length,sepal width,petal length,petal width']
#   id,Class,sepal length,sepal width,petal length,petal width
# 0                      1,Iris-setosa,5.1,3.5,1.4,0.2
# 1                        2,Iris-setosa,4.9,3,1.4,0.2
# 2                      3,Iris-setosa,4.7,3.2,1.3,0.2
# 3                      4,Iris-setosa,4.6,3.1,1.5,0.2
# 4                        5,Iris-setosa,5,3.6,1.4,0.2

# %% [markdown]
# ## Informasi Dataset
#
# Mengecek tipe data tiap kolom, jumlah baris, dan ada tidaknya missing values.

# %%
import pandas as pd
from sklearn.datasets import load_iris
from IPython.display import display

IRIS = load_iris()

columns_clean = [col.replace(" (cm)", "") for col in IRIS.feature_names]
df = pd.DataFrame(data=IRIS.data, columns=columns_clean)

df['species'] = IRIS.target + 1

df['species_name'] = df['species'].map({1: 'setosa', 2: 'versicolor', 3: 'virginica'})

df.insert(0, 'id', range(1, len(df)+1))

print("Dataset Iris berhasil dimuat")
print(f"Ukuran dataset: {df.shape[0]} baris, {df.shape[1]} kolom")

pd.options.display.float_format = "{:.1f}".format

display(
    df.head().style.format("{:.1f}", subset=df.columns[1:5]).hide(axis="index")
)
# Out:
# Dataset Iris berhasil dimuat
# Ukuran dataset: 150 baris, 7 kolom
# <style type="text/css">
# </style>
# <table id="T_b07bb">
#   <thead>
#     <tr>
#       <th id="T_b07bb_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_b07bb_level0_col1" class="col_heading level0 col1" >sepal length</th>
#       <th id="T_b07bb_level0_col2" class="col_heading level0 col2" >sepal width</th>
#       <th id="T_b07bb_level0_col3" class="col_heading level0 col3" >petal length</th>
#       <th id="T_b07bb_level0_col4" class="col_heading level0 col4" >petal width</th>
#       <th id="T_b07bb_level0_col5" class="col_heading level0 col5" >species</th>
#       <th id="T_b07bb_level0_col6" class="col_heading level0 col6" >species_name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b07bb_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_b07bb_row0_col1" class="data row0 col1" >5.1</td>
#       <td id="T_b07bb_row0_col2" class="data row0 col2" >3.5</td>
#       <td id="T_b07bb_row0_col3" class="data row0 col3" >1.4</td>
#       <td id="T_b07bb_row0_col4" class="data row0 col4" >0.2</td>
#       <td id="T_b07bb_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_b07bb_row0_col6" class="data row0 col6" >setosa</td>
#     </tr>
#     <tr>
#       <td id="T_b07bb_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_b07bb_row1_col1" class="data row1 col1" >4.9</td>
#       <td id="T_b07bb_row1_col2" class="data row1 col2" >3.0</td>
#       <td id="T_b07bb_row1_col3" class="data row1 col3" >1.4</td>
#       <td id="T_b07bb_row1_col4" class="data row1 col4" >0.2</td>
#       <td id="T_b07bb_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_b07bb_row1_col6" class="data row1 col6" >setosa</td>
#     </tr>
#     <tr>
#       <td id="T_b07bb_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_b07bb_row2_col1" class="data row2 col1" >4.7</td>
#       <td id="T_b07bb_row2_col2" class="data row2 col2" >3.2</td>
#       <td id="T_b07bb_row2_col3" class="data row2 col3" >1.3</td>
#       <td id="T_b07bb_row2_col4" class="data row2 col4" >0.2</td>
#       <td id="T_b07bb_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_b07bb_row2_col6" class="data row2 col6" >setosa</td>
#     </tr>
#     <tr>
#       <td id="T_b07bb_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_b07bb_row3_col1" class="data row3 col1" >4.6</td>
#       <td id="T_b07bb_row3_col2" class="data row3 col2" >3.1</td>
#       <td id="T_b07bb_row3_col3" class="data row3 col3" >1.5</td>
#       <td id="T_b07bb_row3_col4" class="data row3 col4" >0.2</td>
#       <td id="T_b07bb_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_b07bb_row3_col6" class="data row3 col6" >setosa</td>
#     </tr>
#     <tr>
#       <td id="T_b07bb_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_b07bb_row4_col1" class="data row4 col1" >5.0</td>
#       <td id="T_b07bb_row4_col2" class="data row4 col2" >3.6</td>
#       <td id="T_b07bb_row4_col3" class="data row4 col3" >1.4</td>
#       <td id="T_b07bb_row4_col4" class="data row4 col4" >0.2</td>
#       <td id="T_b07bb_row4_col5" class="data row4 col5" >1</td>
#       <td id="T_b07bb_row4_col6" class="data row4 col6" >setosa</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Mengecek Tipe Data dan Jenis Variabel

# %%
print("\n--- Tipe Data Kolom ---")
print(df.dtypes)

print("\n--- Mengecek Missing Value ---")
print(df.isnull().sum())
# Out:
# --- Tipe Data Kolom ---
# id                int64
# sepal length    float64
# sepal width     float64
# petal length    float64
# petal width     float64
# species           int32
# species_name     object
# dtype: object
#
# --- Mengecek Missing Value ---
# id              0
# sepal length    0
# sepal width     0
# petal length    0
# petal width     0
# species         0
# species_name    0
# dtype: int64

# %% [markdown]
# ## Statistik Deskriptif Data
#
# Menampilkan statistik dasar dari kolom numerik, seperti min, max, mean, dan standar deviasi.

# %%
df.describe()
# Out:
#          id  sepal length  sepal width  petal length  petal width  species
# count 150.0         150.0        150.0         150.0        150.0    150.0
# mean   75.5           5.8          3.1           3.8          1.2      2.0
# std    43.4           0.8          0.4           1.8          0.8      0.8
# min     1.0           4.3          2.0           1.0          0.1      1.0
# 25%    38.2           5.1          2.8           1.6          0.3      1.0
# 50%    75.5           5.8          3.0           4.3          1.3      2.0
# 75%   112.8           6.4          3.3           5.1          1.8      3.0
# max   150.0           7.9          4.4           6.9          2.5      3.0

# %% [markdown]
# ## Statistik Kategori Spesies
#
# Menampilkan jumlah masing-masing spesies iris untuk mengetahui distribusi kelas.

# %%
df['species'].value_counts()
# Out:
# species
# 1    50
# 2    50
# 3    50
# Name: count, dtype: int64
